# %%
import scipy.stats as stats
import numpy as np
import matplotlib.pyplot as plt

data = [4,5,6,6,6,7,8,12,13,13,14,18]

zscores = stats.zscore(data) 
print("Zscoe:")
print (zscores)

find_std = np.std(data)
print('std is:', find_std)

find_mean = np.mean(data)
print('mean value:', find_mean)

find_mode =stats.mode(data)
print('mode value:', find_mode)
# Out:
# Zscoe:
# [-1.2493901  -1.01512945 -0.78086881 -0.78086881 -0.78086881 -0.54660817
#  -0.31234752  0.62469505  0.85895569  0.85895569  1.09321633  2.0302589 ]
# std is: 4.268749491621899
# mean value: 9.333333333333334
# mode value: ModeResult(mode=array([6]), count=array([3]))
# <ipython-input-10-a0b377e73354>:17: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   find_mode =stats.mode(data)

# %%
import matplotlib.pyplot as plt

# Generate random age data


# Create the histogram
plt.hist(data, bins=5, edgecolor='black')

# Customize the plot
plt.title("Age Histogram")
plt.xlabel("Age")
plt.ylabel("Frequency")

# Display the histogram
plt.show()
